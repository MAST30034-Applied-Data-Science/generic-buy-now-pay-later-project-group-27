# %%
import geopandas as gpd

abs = gpd.read_file("../data/ABS/SA2 shapefile/SA2_2021_AUST_GDA2020.shp")[["SA2_CODE21", "geometry"]]
abs = abs[abs["geometry"] != None]
post = gpd.read_file("../data/ABS/post_shapefile/POA_2021_AUST_GDA2020.shp")[["POA_CODE21", "geometry"]]

# %%
gdf = gpd.overlay(abs, post, how="intersection", keep_geom_type=False)

# %%
gdf['area'] = gdf.apply(lambda row: row.geometry.area,axis=1)
gdf = gdf[["SA2_CODE21", "POA_CODE21", "area"]]

# %%
gdf["area%"] = gdf["area"] / gdf.groupby("POA_CODE21")["area"].transform("sum")
gdf["SA2_CODE21"] = gdf["SA2_CODE21"].astype(str)
gdf["POA_CODE21"] = gdf["POA_CODE21"].astype(str)

# %%
gdf[gdf["POA_CODE21"] == "2536"]
# Out:
#   SA2_CODE21 POA_CODE21          area         area%
# 0  101021007       2536  2.436836e-11  2.511085e-10
# 1  101041017       2536  6.344484e-03  6.537797e-02
# 2  101041018       2536  3.049899e-03  3.142828e-02
# 3  101041021       2536  1.547158e-11  1.594300e-10
# 4  101041024       2536  8.764876e-02  9.031937e-01
# 5  101041026       2536  5.054865e-12  5.208884e-11
# 6  114011275       2536  1.983351e-11  2.043783e-10
# 7  114011283       2536  2.975013e-11  3.065660e-10

# %%
import pandas as pd
import numpy as np

raw_data = "../data/ABS/"
curated_data = "../data/curated/"

tbl_income = pd.read_excel(raw_data+"annual income by SA2 regions.xlsx")
tbl_population = pd.read_excel(raw_data+"population estimates by SA2 regions.xlsx")

# %% [markdown]
# <h2>1. Clean external data</h2>

# %% [markdown]
# <h3>1.1 Clean "annual income"</h3>

# %%
tbl_income.drop(np.arange(0,8), inplace=True)
tbl_income.drop(np.arange(2303,2306), inplace=True)

tbl_income.drop(tbl_income.columns[[2,3,4,5,7,8,9,10,12,13,14,15,17,18,19,20,22,23,24,25,27]], axis=1, inplace=True)
tbl_income = tbl_income.reset_index(drop=True)
tbl_income.columns = ['sa2', 'sa2_name', 'total_earners', 'median_age', 'income_sum', 'income_median', 'income_mean']
tbl_income["sa2"] = tbl_income["sa2"].astype(str)
tbl_income
# Out:
#             sa2           sa2_name total_earners median_age  income_sum  \
# 0     101021007          Braidwood          2361         51   120763285
# 1     101021008            Karabar          5100         42   338308979
# 2     101021009         Queanbeyan          6697         39   441160946
# 3     101021010  Queanbeyan - East          3393         40   237035656
# 4     101021011  Queanbeyan Region         12821         44  1050285692
# ...         ...                ...           ...        ...         ...
# 2290  801101137           Molonglo            np         np          np
# 2291  801101138   Molonglo - North            np         np          np
# 2292  801101139             Wright          2121         35   182421537
# 2293  801111140   ACT - South West           355         40    26069449
# 2294  801111141            Namadgi            18         27      706999
#
#      income_median income_mean
# 0            41593       51149
# 1            61777       66335
# 2            60119       65874
# 3            63051       69860
# 4            71420       81919
# ...            ...         ...
# 2290            np          np
# 2291            np          np
# 2292         79150       86007
# 2293         64227       73435
# 2294         40479       39278
#
# [2295 rows x 7 columns]

# %%
stats = tbl_income.columns[2:]
to_do = []
for i in stats:
    to_do += list(tbl_income[tbl_income[i] == "np"]["sa2"])
to_do = set(to_do)
abs["neighbours"] = None
for i, sa2 in abs.iterrows():
    if sa2.SA2_CODE21 in to_do:
        neighbours = abs[~abs.geometry.disjoint(sa2.geometry)].SA2_CODE21.tolist()
        neighbours = [ name for name in neighbours if sa2.SA2_CODE21 != name ]
        abs.at[i, "neighbours"] = neighbours

# %%
neighbours = abs.set_index("SA2_CODE21")["neighbours"].to_dict()
neighbours = {i: neighbours[i] for i in neighbours if neighbours[i]}
tbl_income_clean = tbl_income.merge(abs[["SA2_CODE21", "neighbours"]], left_on="sa2", right_on="SA2_CODE21")

while neighbours:
    for i in neighbours:
        try:
            cur = {}
            for j in stats:
                cur[j] = tbl_income_clean[tbl_income_clean["sa2"].isin(neighbours[i])][j].mean()
            neighbours[i] = cur
        except:
            pass
    cur = {i: neighbours[i] for i in neighbours if type(neighbours[i]) == dict}
    neighbours = {i: neighbours[i] for i in neighbours if i not in cur}
    for i, data in tbl_income_clean.iterrows():
        for j in stats:
            if data[j] == "np" and data.sa2 in cur:
                tbl_income_clean.at[i,j] = cur[data.sa2][j]
    for i in neighbours:
        neighbours[i] = [j for j in neighbours[i] if j not in neighbours]
tbl_income_clean = tbl_income_clean.drop(["SA2_CODE21", "neighbours"], axis=1)
tbl_income_clean
# Out:
#             sa2                         sa2_name total_earners median_age  \
# 0     101021007                        Braidwood          2361         51
# 1     101021008                          Karabar          5100         42
# 2     101021009                       Queanbeyan          6697         39
# 3     101021010                Queanbeyan - East          3393         40
# 4     101021012  Queanbeyan West - Jerrabomberra          8476         44
# ...         ...                              ...           ...        ...
# 2142  801101136                  Denman Prospect           416         38
# 2143  801101137                         Molonglo   1602.333333       36.0
# 2144  801101139                           Wright          2121         35
# 2145  801111140                 ACT - South West           355         40
# 2146  801111141                          Namadgi            18         27
#
#             income_sum income_median   income_mean
# 0            120763285         41593         51149
# 1            338308979         61777         66335
# 2            441160946         60119         65874
# 3            237035656         63051         69860
# 4            725602722         73851         85607
# ...                ...           ...           ...
# 2142          41056005         90337         98692
# 2143  134437238.666667       81222.0  87973.666667
# 2144         182421537         79150         86007
# 2145          26069449         64227         73435
# 2146            706999         40479         39278
#
# [2147 rows x 7 columns]

# %%
to_do1 = []
for i in tbl_income_clean.columns[2:]:
    to_do1 += list(tbl_income_clean[tbl_income_clean[i] == "np"]["sa2"])
to_do1 = set(to_do1)
to_do1 # this is Torrens Island, a small island home to 2 electric power plants so safe to ignore
# Out:
# {'404021103'}

# %%
tbl_income_clean = tbl_income_clean[tbl_income_clean["sa2"] != "404021103"]

# %%
tbl_income_clean.to_csv(curated_data+"clean_annual.csv")

# %% [markdown]
# <h3>1.2 Clean "population"</h3>

# %%
tbl_population.drop(tbl_population.columns[0:8], axis=1, inplace=True)
tbl_population.drop(tbl_population.columns[1:22], axis=1, inplace=True)
tbl_population.drop(tbl_population.columns[2:6], axis=1, inplace=True)

# %%
tbl_population.columns = ["sa2", "2021_population", "km2", "persons/km2"]
tbl_population = tbl_population.dropna(axis=0, how='any', thresh=None, subset=["sa2"], inplace=False)
tbl_population['sa2'] = tbl_population['sa2'].astype(int).astype(str)
tbl_population
# Out:
#             sa2  2021_population     km2  persons/km2
# 0     101021007           4330.0  3418.4          1.3
# 1     101021008           8546.0     7.0       1223.9
# 2     101021009          11370.0     4.8       2387.7
# 3     101021010           5093.0    13.0        391.7
# 4     101021012          12743.0    13.7        931.9
# ...         ...              ...     ...          ...
# 2449  801111141             67.0  1202.8          0.1
# 2450  901011001           1716.0   136.1         12.6
# 2451  901021002            602.0    13.7         43.9
# 2452  901031003            310.0    67.2          4.6
# 2453  901041004           2220.0    38.7         57.4
#
# [2454 rows x 4 columns]

# %%
tbl_population.to_csv(curated_data+"clean_population.csv")

# %% [markdown]
# <h2>2. Join external data</h2>

# %%
merge_income_population = tbl_income_clean.merge(tbl_population, on='sa2', how='inner')
merge_income_population
# Out:
#             sa2                         sa2_name total_earners median_age  \
# 0     101021007                        Braidwood          2361         51
# 1     101021008                          Karabar          5100         42
# 2     101021009                       Queanbeyan          6697         39
# 3     101021010                Queanbeyan - East          3393         40
# 4     101021012  Queanbeyan West - Jerrabomberra          8476         44
# ...         ...                              ...           ...        ...
# 2141  801101136                  Denman Prospect           416         38
# 2142  801101137                         Molonglo   1602.333333       36.0
# 2143  801101139                           Wright          2121         35
# 2144  801111140                 ACT - South West           355         40
# 2145  801111141                          Namadgi            18         27
#
#             income_sum income_median   income_mean  2021_population     km2  \
# 0            120763285         41593         51149           4330.0  3418.4
# 1            338308979         61777         66335           8546.0     7.0
# 2            441160946         60119         65874          11370.0     4.8
# 3            237035656         63051         69860           5093.0    13.0
# 4            725602722         73851         85607          12743.0    13.7
# ...                ...           ...           ...              ...     ...
# 2141          41056005         90337         98692           2719.0     4.7
# 2142  134437238.666667       81222.0  87973.666667              0.0     2.2
# 2143         182421537         79150         86007           3806.0     1.3
# 2144          26069449         64227         73435            554.0   416.8
# 2145            706999         40479         39278             67.0  1202.8
#
#       persons/km2
# 0             1.3
# 1          1223.9
# 2          2387.7
# 3           391.7
# 4           931.9
# ...           ...
# 2141        573.2
# 2142          0.0
# 2143       2993.1
# 2144          1.3
# 2145          0.1
#
# [2146 rows x 10 columns]

# %%
merge_post_sa2 = gdf.merge(merge_income_population, left_on="SA2_CODE21", right_on="sa2", how="inner")
stats = merge_post_sa2.columns[6:]
for i in stats:
    merge_post_sa2[i] = merge_post_sa2["area%"] * merge_post_sa2[i].astype(float)
merge_post_sa2
# Out:
#       SA2_CODE21 POA_CODE21          area         area%        sa2  \
# 0      101021007       2536  2.436836e-11  2.511085e-10  101021007
# 1      101021007       2537  3.274170e-11  2.809841e-10  101021007
# 2      101021007       2545  1.716204e-11  1.956121e-10  101021007
# 3      101021007       2580  5.258742e-02  9.695094e-02  101021007
# 4      101021007       2621  2.399097e-11  2.832682e-10  101021007
# ...          ...        ...           ...           ...        ...
# 11821  801071079       2903  1.270430e-12  1.974653e-09  801071079
# 11822  801071081       2904  4.374485e-12  4.520853e-09  801071081
# 11823  801071081       2905  2.476339e-04  1.259155e-01  801071081
# 11824  801071087       2904  1.260680e-12  1.302861e-09  801071087
# 11825  801071087       2905  2.220398e-04  1.129016e-01  801071087
#
#               sa2_name  total_earners    median_age    income_sum  \
# 0            Braidwood   5.928672e-07  1.280653e-08  3.032469e-02
# 1            Braidwood   6.634034e-07  1.433019e-08  3.393256e-02
# 2            Braidwood   4.618402e-07  9.976218e-09  2.362276e-02
# 3            Braidwood   2.289012e+02  4.944498e+00  1.170811e+07
# 4            Braidwood   6.687961e-07  1.444668e-08  3.420839e-02
# ...                ...            ...           ...           ...
# 11821     Gowrie (ACT)   4.046063e-06  8.688471e-08  2.949746e-01
# 11822  Isabella Plains   1.269004e-05  1.853550e-07  8.446155e-01
# 11823  Isabella Plains   3.534448e+02  5.162535e+00  2.352436e+07
# 11824       Richardson   2.519734e-06  5.341731e-08  1.627368e-01
# 11825       Richardson   2.183516e+02  4.628965e+00  1.410222e+07
#
#        income_median  income_mean  2021_population           km2   persons/km2
# 0           0.000010     0.000013     1.087300e-06  8.583894e-07  3.264411e-10
# 1           0.000012     0.000014     1.216661e-06  9.605159e-07  3.652793e-10
# 2           0.000008     0.000010     8.470005e-07  6.686805e-07  2.542957e-10
# 3        4032.480388  4958.943558     4.197976e+02  3.314171e+02  1.260362e-01
# 4           0.000012     0.000014     1.226551e-06  9.683239e-07  3.682486e-10
# ...              ...          ...              ...           ...           ...
# 11821       0.000129     0.000144     6.172764e-06  3.751840e-09  3.195580e-06
# 11822       0.000283     0.000301     1.954817e-05  1.130213e-08  7.835091e-06
# 11823    7891.879623  8380.557663     5.444586e+02  3.147887e-01  2.182241e+02
# 11824       0.000079     0.000084     3.969818e-06  2.866295e-09  1.774497e-06
# 11825    6803.674825  7291.748341     3.440111e+02  2.483835e-01  1.537719e+02
#
# [11826 rows x 14 columns]

# %%
post_sa2_agg = merge_post_sa2.groupby("POA_CODE21").sum().reset_index()
post_sa2_agg.drop(["area", "area%"], axis=1, inplace=True)
post_sa2_agg.rename({"POA_CODE21": "postcode"}, axis=1, inplace=True)
post_sa2_agg
# Out:
#      postcode  total_earners  median_age    income_sum  income_median  \
# 0        0800    5631.999974   33.000000  4.206090e+08   57789.000082
# 1        0810    2247.557682   38.689316  1.709450e+08   64195.425046
# 2        0812    2177.164726   39.676957  1.583888e+08   63606.250469
# 3        0820    1313.062168   39.800996  1.045872e+08   62694.098403
# 4        0822     899.191123   40.878605  4.633381e+07   36623.557892
# ...       ...            ...         ...           ...            ...
# 2629     7466    1984.999996   45.000000  1.157059e+08   49788.999965
# 2630     7467    1984.999999   45.000000  1.157059e+08   49788.999992
# 2631     7468    1984.999999   45.000000  1.157059e+08   49788.999992
# 2632     7469    2140.391676   45.756209  1.119052e+08   45800.898515
# 2633     7470    1985.000000   45.000000  1.157059e+08   49789.000000
#
#        income_mean  2021_population           km2  persons/km2
# 0     74682.000125      7678.999968      3.200000  2419.999994
# 1     73447.813891      3872.057394      3.353824  1482.569926
# 2     72132.529895      1453.078809     16.957135   554.150966
# 3     71491.215692      1836.446110      9.143080   541.657373
# 4     44584.908043      4905.148329  31941.621280     0.250779
# ...            ...              ...           ...          ...
# 2629  58289.999976      4372.999980   3931.600008     1.100000
# 2630  58289.999995      4372.999996   3931.600002     1.100000
# 2631  58289.999994      4372.999995   3931.600002     1.100000
# 2632  52653.496678      4241.731828   4105.857702     1.044130
# 2633  58290.000000      4373.000000   3931.600000     1.100000
#
# [2634 rows x 9 columns]

# %%
merchant_consumer_info = pd.read_parquet(curated_data+"merchant_consumer_info")
merchant_consumer_info["consumer_postcode"] = merchant_consumer_info["consumer_postcode"].str.pad(width=4, fillchar="0", side="left")

# %%
merchant_consumer_info["consumer_postcode"].unique()
# Out:
# array(['6947', '2805', '5063', ..., '3921', '1120', '3205'], dtype=object)

# %%
final_table = post_sa2_agg.merge(merchant_consumer_info, left_on='postcode', right_on='consumer_postcode', how='inner')
# len(final_table[final_table["income_sum"].isnull()]["consumer_postcode"].unique())
print(f"Mismatched (null) transactions dropped: {merchant_consumer_info.shape[0] - final_table.shape[0]}")
# Out:
# Mismatched (null) transactions dropped: 2218439

# %%
final_table
# Out:
#          postcode  total_earners  median_age    income_sum  income_median  \
# 0            0800    5631.999974        33.0  4.206090e+08   57789.000082
# 1            0800    5631.999974        33.0  4.206090e+08   57789.000082
# 2            0800    5631.999974        33.0  4.206090e+08   57789.000082
# 3            0800    5631.999974        33.0  4.206090e+08   57789.000082
# 4            0800    5631.999974        33.0  4.206090e+08   57789.000082
# ...           ...            ...         ...           ...            ...
# 11087920     7470    1985.000000        45.0  1.157059e+08   49789.000000
# 11087921     7470    1985.000000        45.0  1.157059e+08   49789.000000
# 11087922     7470    1985.000000        45.0  1.157059e+08   49789.000000
# 11087923     7470    1985.000000        45.0  1.157059e+08   49789.000000
# 11087924     7470    1985.000000        45.0  1.157059e+08   49789.000000
#
#            income_mean  2021_population     km2  persons/km2  \
# 0         74682.000125      7678.999968     3.2  2419.999994
# 1         74682.000125      7678.999968     3.2  2419.999994
# 2         74682.000125      7678.999968     3.2  2419.999994
# 3         74682.000125      7678.999968     3.2  2419.999994
# 4         74682.000125      7678.999968     3.2  2419.999994
# ...                ...              ...     ...          ...
# 11087920  58290.000000      4373.000000  3931.6     1.100000
# 11087921  58290.000000      4373.000000  3931.6     1.100000
# 11087922  58290.000000      4373.000000  3931.6     1.100000
# 11087923  58290.000000      4373.000000  3931.6     1.100000
# 11087924  58290.000000      4373.000000  3931.6     1.100000
#
#                           merchant_name  ... dollar_value  order_year  \
# 0         Elit Sed Consequat Associates  ...   375.167732        2022
# 1         Elit Sed Consequat Associates  ...   617.879131        2022
# 2         Elit Sed Consequat Associates  ...   766.507707        2022
# 3                     Malesuada Vel Ltd  ...   258.865959        2021
# 4                 Varius Orci Institute  ...     4.159038        2021
# ...                                 ...  ...          ...         ...
# 11087920        Ipsum Primis Associates  ...    56.702387        2021
# 11087921        Ipsum Primis Associates  ...    84.885059        2022
# 11087922               Lorem Foundation  ...    41.906740        2021
# 11087923               Lorem Foundation  ...     9.540977        2022
# 11087924     Purus Gravida Sagittis Ltd  ...    95.787014        2021
#
#          order_month order_day         consumer  \
# 0                  4        27    Kelly Clayton
# 1                 10         7    Corey Estrada
# 2                  2        28    Nicole Bishop
# 3                  7        24  Natalie Herrera
# 4                  8         8     Shannon Mann
# ...              ...       ...              ...
# 11087920           7        17    Shannon Petty
# 11087921           3        11     Michael Bush
# 11087922           5        12      Kevin Brown
# 11087923           1         6      Kevin Brown
# 11087924          10        27     Michael Bush
#
#                        consumer_address  consumer_state  consumer_postcode  \
# 0          4211 Rodney Tunnel Suite 525              NT               0800
# 1                       1703 Boyd Shore              NT               0800
# 2           467 Robert Islands Apt. 834              NT               0800
# 3         88798 Saunders Hills Apt. 945              NT               0800
# 4                    00817 Owens Circle              NT               0800
# ...                                 ...             ...                ...
# 11087920               386 Aaron Manors             TAS               7470
# 11087921   47924 Jessica Drive Apt. 344             TAS               7470
# 11087922   1861 Tina Junction Suite 680             TAS               7470
# 11087923   1861 Tina Junction Suite 680             TAS               7470
# 11087924   47924 Jessica Drive Apt. 344             TAS               7470
#
#           consumer_gender  fraud_group
# 0                  Female            0
# 1                    Male            0
# 2                  Female            0
# 3                  Female            0
# 4                  Female            0
# ...                   ...          ...
# 11087920           Female            0
# 11087921             Male            0
# 11087922      Undisclosed            0
# 11087923      Undisclosed            0
# 11087924             Male            0
#
# [11087925 rows x 26 columns]

# %%
final_table.to_parquet("../data/curated/merchant_consumer_abs")

# %%
len(set(merchant_consumer_info["consumer_postcode"].unique()) - set(post["POA_CODE21"].unique()))
# Out:
# 527

# %%
post["POA_CODE21"].unique()
# Out:
# array(['0800', '0810', '0812', ..., '9494', '9797', 'ZZZZ'], dtype=object)

# %%
set(merchant_consumer_info["consumer_postcode"].unique()) - set(post["POA_CODE21"].unique())
# Out:
# {'0200',
#  '0801',
#  '0804',
#  '0811',
#  '0813',
#  '0814',
#  '0815',
#  '0821',
#  '0831',
#  '0851',
#  '0861',
#  '0871',
#  '0881',
#  '0906',
#  '0907',
#  '0909',
#  '1001',
#  '1002',
#  '1003',
#  '1004',
#  '1005',
#  '1006',
#  '1007',
#  '1008',
#  '1009',
#  '1010',
#  '1020',
#  '1021',
#  '1022',
#  '1023',
#  '1025',
#  '1026',
#  '1027',
#  '1028',
#  '1029',
#  '1030',
#  '1031',
#  '1032',
#  '1033',
#  '1034',
#  '1035',
#  '1036',
#  '1037',
#  '1038',
#  '1039',
#  '1040',
#  '1041',
#  '1042',
#  '1043',
#  '1044',
#  '1045',
#  '1046',
#  '1100',
#  '1101',
#  '1105',
#  '1106',
#  '1107',
#  '1108',
#  '1109',
#  '1110',
#  '1112',
#  '1113',
#  '1114',
#  '1115',
#  '1116',
#  '1117',
#  '1118',
#  '1119',
#  '1120',
#  '1121',
#  '1122',
#  '1123',
#  '1124',
#  '1125',
#  '1126',
#  '1127',
#  '1128',
#  '1129',
#  '1130',
#  '1131',
#  '1132',
#  '1133',
#  '1134',
#  '1135',
#  '1136',
#  '1137',
#  '1138',
#  '1139',
#  '1140',
#  '1141',
#  '1142',
#  '1143',
#  '1144',
#  '1145',
#  '1146',
#  '1147',
#  '1148',
#  '1149',
#  '1150',
#  '1151',
#  '1152',
#  '1153',
#  '1154',
#  '1155',
#  '1156',
#  '1157',
#  '1158',
#  '1159',
#  '1160',
#  '1161',
#  '1162',
#  '1163',
#  '1164',
#  '1165',
#  '1166',
#  '1167',
#  '1168',
#  '1169',
#  '1170',
#  '1171',
#  '1172',
#  '1173',
#  '1174',
#  '1175',
#  '1176',
#  '1177',
#  '1178',
#  '1179',
#  '1180',
#  '1181',
#  '1182',
#  '1183',
#  '1184',
#  '1185',
#  '1186',
#  '1187',
#  '1188',
#  '1189',
#  '1190',
#  '1191',
#  '1192',
#  '1193',
#  '1194',
#  '1195',
#  '1196',
#  '1197',
#  '1198',
#  '1199',
#  '1201',
#  '1202',
#  '1203',
#  '1205',
#  '1207',
#  '1208',
#  '1209',
#  '1210',
#  '1211',
#  '1212',
#  '1213',
#  '1214',
#  '1215',
#  '1216',
#  '1217',
#  '1218',
#  '1219',
#  '1220',
#  '1221',
#  '1222',
#  '1223',
#  '1224',
#  '1225',
#  '1226',
#  '1227',
#  '1228',
#  '1229',
#  '1230',
#  '1231',
#  '1232',
#  '1233',
#  '1234',
#  '1235',
#  '1236',
#  '1237',
#  '1238',
#  '1239',
#  '1240',
#  '1291',
#  '1292',
#  '1293',
#  '1294',
#  '1295',
#  '1296',
#  '1297',
#  '1298',
#  '1299',
#  '1300',
#  '1314',
#  '1335',
#  '1340',
#  '1350',
#  '1355',
#  '1360',
#  '1401',
#  '1419',
#  '1420',
#  '1422',
#  '1423',
#  '1424',
#  '1425',
#  '1426',
#  '1427',
#  '1428',
#  '1429',
#  '1430',
#  '1435',
#  '1440',
#  '1441',
#  '1445',
#  '1450',
#  '1455',
#  '1460',
#  '1465',
#  '1466',
#  '1470',
#  '1475',
#  '1476',
#  '1480',
#  '1481',
#  '1484',
#  '1485',
#  '1490',
#  '1493',
#  '1495',
#  '1499',
#  '1515',
#  '1560',
#  '1565',
#  '1570',
#  '1585',
#  '1590',
#  '1595',
#  '1597',
#  '1602',
#  '1630',
#  '1635',
#  '1639',
#  '1640',
#  '1655',
#  '1658',
#  '1660',
#  '1670',
#  '1675',
#  '1680',
#  '1685',
#  '1700',
#  '1710',
#  '1715',
#  '1730',
#  '1740',
#  '1741',
#  '1750',
#  '1755',
#  '1765',
#  '1771',
#  '1781',
#  '1790',
#  '1800',
#  '1805',
#  '1811',
#  '1819',
#  '1825',
#  '1830',
#  '1831',
#  '1835',
#  '1851',
#  '1860',
#  '1871',
#  '1875',
#  '1885',
#  '1888',
#  '1890',
#  '1891',
#  '2001',
#  '2002',
#  '2004',
#  '2006',
#  '2012',
#  '2013',
#  '2052',
#  '2055',
#  '2057',
#  '2058',
#  '2059',
#  '2091',
#  '2109',
#  '2123',
#  '2124',
#  '2129',
#  '2139',
#  '2252',
#  '2309',
#  '2310',
#  '2314',
#  '2348',
#  '2351',
#  '2442',
#  '2520',
#  '2522',
#  '2608',
#  '2610',
#  '2616',
#  '2708',
#  '2751',
#  '2755',
#  '2890',
#  '2891',
#  '2901',
#  '3001',
#  '3005',
#  '3010',
#  '3050',
#  '3086',
#  '3164',
#  '3176',
#  '3353',
#  '3354',
#  '3399',
#  '3402',
#  '3502',
#  '3552',
#  '3554',
#  '3619',
#  '3632',
#  '3643',
#  '3661',
#  '3671',
#  '3676',
#  '3689',
#  '3694',
#  '3724',
#  '3736',
#  '3800',
#  '3841',
#  '3853',
#  '3989',
#  '4001',
#  '4002',
#  '4003',
#  '4004',
#  '4029',
#  '4072',
#  '4219',
#  '4222',
#  '4229',
#  '4230',
#  '4271',
#  '4345',
#  '4471',
#  '4475',
#  '4801',
#  '4803',
#  '4813',
#  '4857',
#  '5001',
#  '5005',
#  '5071',
#  '5800',
#  '5810',
#  '5839',
#  '5942',
#  '6001',
#  '6231',
#  '6331',
#  '6332',
#  '6433',
#  '6435',
#  '6531',
#  '6711',
#  '6723',
#  '6731',
#  '6733',
#  '6761',
#  '6800',
#  '6803',
#  '6809',
#  '6817',
#  '6820',
#  '6827',
#  '6830',
#  '6831',
#  '6832',
#  '6837',
#  '6838',
#  '6839',
#  '6840',
#  '6841',
#  '6842',
#  '6843',
#  '6844',
#  '6845',
#  '6846',
#  '6847',
#  '6848',
#  '6849',
#  '6850',
#  '6865',
#  '6872',
#  '6892',
#  '6900',
#  '6901',
#  '6902',
#  '6903',
#  '6904',
#  '6905',
#  '6906',
#  '6907',
#  '6909',
#  '6910',
#  '6911',
#  '6912',
#  '6913',
#  '6914',
#  '6915',
#  '6916',
#  '6917',
#  '6918',
#  '6919',
#  '6920',
#  '6921',
#  '6922',
#  '6923',
#  '6924',
#  '6925',
#  '6926',
#  '6929',
#  '6931',
#  '6932',
#  '6933',
#  '6934',
#  '6935',
#  '6936',
#  '6937',
#  '6938',
#  '6939',
#  '6940',
#  '6941',
#  '6942',
#  '6943',
#  '6944',
#  '6945',
#  '6946',
#  '6947',
#  '6951',
#  '6952',
#  '6953',
#  '6954',
#  '6955',
#  '6956',
#  '6957',
#  '6958',
#  '6959',
#  '6960',
#  '6961',
#  '6963',
#  '6964',
#  '6965',
#  '6966',
#  '6967',
#  '6968',
#  '6969',
#  '6970',
#  '6979',
#  '6980',
#  '6981',
#  '6982',
#  '6983',
#  '6984',
#  '6985',
#  '6986',
#  '6987',
#  '6988',
#  '6989',
#  '6990',
#  '6991',
#  '6992',
#  '6997',
#  '7001',
#  '7002',
#  '7006',
#  '7051',
#  '7151',
#  '8001',
#  '8002',
#  '8003',
#  '8004',
#  '8005',
#  '8006',
#  '8007',
#  '8008',
#  '8009',
#  '8010',
#  '8011',
#  '8012',
#  '8045',
#  '8051',
#  '8066',
#  '8069',
#  '8070',
#  '8071',
#  '8102',
#  '8107',
#  '8111',
#  '8120',
#  '8205',
#  '8785',
#  '9000',
#  '9001',
#  '9002',
#  '9005',
#  '9007',
#  '9009',
#  '9010',
#  '9013',
#  '9015',
#  '9464',
#  '9726',
#  '9999'}
